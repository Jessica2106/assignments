# %% [markdown]
# # Exam
#
# In this exam, we will work with the "frequently requested health data” from the OECD.
# Your task is to compute a simple “efficiency score” and make three plots.
#
#
# You will earn a higher grade if you provide nicer graphs.
#
# |name | student number|
# |----|----|
# |Jessica de Leeuw| 1274544|

# %% [markdown]
# Now you need to call the libaries
#
# * ggplot2
# * dplyr

# %%
library(ggplot2)
library(dplyr)

# %% [markdown]
# **I imported the libraries: ggplot2 and dplyr.**

# %% [markdown]
# Now you have to read the de data that we have cleaned during tutorial 3. The csv file is called oecddata.csv

# %%
oecd <- read.csv2("oecddata.csv", sep=";")

# %% [markdown]
# **I read the data of the csv file and called the dataframe oecd.**

# %% [markdown]
# To see how the data look like, use the command:
#
# head(oecd)
#
# With the command
#
# oecd
#
#
# You can see the dataset in total.

# %%
head(oecd)
oecd
# Out:
#   X Country   Year Cost     LE
# 1 1 Australia 2005 2842.132 80.9
# 2 2 Australia 2006 3023.098 81.1
# 3 3 Australia 2007 3196.226 81.4
# 4 4 Australia 2008 3310.171 81.5
# 5 5 Australia 2009 3564.405 81.6
# 6 6 Australia 2010 3607.341 81.8
#     X   Country        Year Cost      LE
# 1    1  Australia      2005 2842.132  80.9
# 2    2  Australia      2006 3023.098  81.1
# 3    3  Australia      2007 3196.226  81.4
# 4    4  Australia      2008 3310.171  81.5
# 5    5  Australia      2009 3564.405  81.6
# 6    6  Australia      2010 3607.341  81.8
# 7    7  Australia      2011 3794.087  82.0
# 8    8  Australia      2012 3807.682  82.1
# 9    9  Australia      2013 4176.853  82.2
# 10  10  Australia      2014 4206.852  82.4
# 11  11  Australia      2015 4420.436    NA
# 12  12  Austria        2005 3324.079  79.4
# 13  13  Austria        2006 3567.649  80.0
# 14  14  Austria        2007 3718.739  80.3
# 15  15  Austria        2008 3964.849  80.5
# ...

# %% [markdown]
# **You can now see the head of the dataset and the dataset in total.**

# %% [markdown]
# ## Graphs

# %% [markdown]
# To make the graphs we need to make selections of the data. Please use "dplyr" (commands "select" and "filter") and the "pipe". The first assignment is to make a scatterplot using "ggplot". The graph contains data for all countries for the year 2014. Therefore make a dataframe with dplyr first, called "graph1" with the required data.
# Then, make a scatterplot with "Cost" on the x-axis and "LE" on the y-axis. You have to add a regression line with a shaded area for the confidence interval.

# %%
graph1 <- oecd %>% 
    filter(Year == 2014) %>%
    select(Country, Cost, LE)
graph1
# Out:
#    Country         Cost      LE
# 1  Australia       4206.8516 82.4
# 2  Austria         4895.9992 81.6
# 3  Belgium         4522.0450 81.4
# 4  Canada          4491.7648   NA
# 5  Chile           1688.5233 79.0
# 6  Czech Republic  2386.3385 78.9
# 7  Denmark         4857.0285 80.8
# 8  Estonia         1724.5100 77.2
# 9  Finland         3870.4000 81.3
# 10 France          4366.9864 82.8
# 11 Germany         5119.2146 81.2
# 12 Greece          2220.1065 81.5
# 13 Hungary         1796.6034 75.9
# 14 Iceland         3896.9251 82.9
# 15 Ireland         5001.3220 81.4
# 16 Israel          2547.4010 82.2
# 17 Italy           3206.8286 83.2
# 18 Japan           4152.3727 83.7
# 19 Korea           2361.4400 82.2
# 20 Latvia          1295.0128 74.3
# 21 Luxembourg      6682.2370 82.3
# 22 Mexico          1035.3389 74.8
# 23 Netherlands     5276.6003 81.8
# 24 New Zealand     3537.2568 81.6
# 25 Norway          6080.9980 82.2
# 26 Poland          1624.8655 77.7
# ...

# %% [markdown]
# **I made a dataframe containing the required data only. I used filter to get the data from the year 2014. Then I used select so that I would only get the columns I needed. I called the dataset graph1.**

# %%
ggplot(graph1, aes(x=Cost, y=LE, label=Country)) + geom_point(colour = "red", shape=15) +
    geom_smooth(method=lm, col="yellow") + 
    geom_text(check_overlap = TRUE, size = 2) +
    theme(text = element_text(size=12), axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# Warning message:
# "Removed 1 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 1 rows containing missing values (geom_point)."Warning message:
# "Removed 1 rows containing missing values (geom_text)."
# plot without title

# %% [markdown]
# **I made a scatterplot with ggplot. Geom_point indicates a scatterplot. By adding geom_smooth I created a linear regression line. lm between the brackets stands for a linear regression. The shaded area shows the 95% confidence interval. As you can see in the warning, the LE of Canada is not available. **

# %% [markdown]
# The second assignment is to make a line graph. You will use the years 2005-2015 for 5 countries (you can choose your own countries). Make a new dataframe called graph2 with the required data. Then, make a line graph with "Year"  and "Cost" on the y-axis. There should be coloured lines per country and a legend attached.

# %%
graph2 <- oecd %>% 
    select(Country, Year, Cost) %>%
    filter(Country %in% c("Germany", "Italy", "Luxembourg", "Netherlands", "Spain"))
graph2
# Out:
#    Country     Year Cost
# 1  Germany     2005 3297.059
# 2  Germany     2006 3502.691
# 3  Germany     2007 3660.935
# 4  Germany     2008 3901.418
# 5  Germany     2009 4130.797
# 6  Germany     2010 4358.613
# 7  Germany     2011 4510.175
# 8  Germany     2012 4694.681
# 9  Germany     2013 4921.814
# 10 Germany     2014 5119.215
# 11 Germany     2015 5267.138
# 12 Italy       2005 2479.328
# 13 Italy       2006 2703.163
# 14 Italy       2007 2751.852
# 15 Italy       2008 3011.273
# 16 Italy       2009 3064.800
# 17 Italy       2010 3108.204
# 18 Italy       2011 3169.049
# 19 Italy       2012 3174.261
# 20 Italy       2013 3141.865
# 21 Italy       2014 3206.829
# 22 Italy       2015 3272.253
# 23 Luxembourg  2005 5090.367
# 24 Luxembourg  2006 5512.894
# 25 Luxembourg  2007 5500.600
# 26 Luxembourg  2008 5938.808
# 27 Luxembourg  2009 6355.545
# 28 Luxembourg  2010 6401.897
# 29 Luxembourg  2011 6040.591
# 30 Luxembourg  2012 6423.165
# 31 Luxembourg  2013 6629.028
# ...

# %% [markdown]
# **I made a dataframe with the required data and called it graph2. Again I used the commands select and filter. I chose for the 5 countries: Germany, Italy, Luxembourg, Netherlans and Spain.**

# %%
ggplot(graph2, aes(x=Year, y=Cost, color=Country)) + geom_line() +
    theme(text = element_text(size=12), axis.text.x = element_text(angle = 45, hjust = 1)) +
    scale_x_continuous(breaks = seq(2005,2015,1))
# Out:
# plot without title

# %% [markdown]
# **With ggplot I made a line graph. Geom_line indicates a line graph. Bij adding color=Country I got the coloured lines per country. A legend is automatically generated.**

# %% [markdown]
# ## Efficiency scores
#
# The last assignment is to compute simple effiency scores. We will use the year 2014 for all countries (i.e. the dataframe "graph1").
# Make a new dateframe called "eff" (using graph1). Please use the "pipe" to execute to following steps:
# Select all the variables except the NA's (hint: use na.omit) and create a new column called "Ratio" with mutate. Ratio is defined as "Cost/LE" (cost per output).
# Create a new column called "Score" with mutate. Score is the ratio per country divided by the lowest ratio in the dataframe.
# To complete this dataframe order the dataset using "arrange" based on score (i.e. lowest Score first).
#
#
# Finally make a bar chart using ggplot. Countries should be on the x-axis and "Score" on the y-axis.
#
#
#
# You can earn extra points if you are able to order the graph based on scores (lowest first, highest last), if you are able to make the x-axis readable, make the bar of the Netherlands red and the other bars blue and/or change the name of the y-axis to "Efficiency scores according to [your name]"
#
#
# The figure should like this:
#
# ![My Figure](eff.png)

# %%
eff <- graph1 %>% 
    filter(!is.na(LE)) %>%
    mutate(Ratio = Cost/LE) %>%
    mutate(Score = min(Ratio)/Ratio) %>%
    arrange(Score)
eff
# Out:
#    Country         Cost      LE   Ratio     Score
# 1  United States   9024.2064 78.8 114.52039 0.1108515
# 2  Switzerland     6786.5657 83.3  81.47138 0.1558186
# 3  Luxembourg      6682.2370 82.3  81.19365 0.1563516
# 4  Norway          6080.9980 82.2  73.97808 0.1716016
# 5  Netherlands     5276.6003 81.8  64.50612 0.1967992
# 6  Germany         5119.2146 81.2  63.04451 0.2013618
# 7  Sweden          5065.1613 82.3  61.54509 0.2062675
# 8  Ireland         5001.3220 81.4  61.44130 0.2066160
# 9  Denmark         4857.0285 80.8  60.11174 0.2111859
# 10 Austria         4895.9992 81.6  59.99999 0.2115793
# 11 Belgium         4522.0450 81.4  55.55338 0.2285145
# 12 France          4366.9864 82.8  52.74138 0.2406982
# 13 Australia       4206.8516 82.4  51.05402 0.2486533
# 14 Japan           4152.3727 83.7  49.61019 0.2558901
# 15 United Kingdom  3971.3940 81.4  48.78862 0.2601991
# 16 Finland         3870.4000 81.3  47.60640 0.2666607
# ...

# %% [markdown]
# **I made a new dataframe using graph1 and called it eff. With filter I removed all the rows with NA's. I created two new columns, Ratio and Score, with mutate. Then I orderded the dataframe from lowest score to highest score with the command arrange.**

# %%
ggplot(eff, aes(x=reorder(Country, Score), y=Score, fill=Country)) + geom_bar(stat = "identity") +
scale_fill_manual(values = c('blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'red', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue')) +
guides(fill=FALSE) +
scale_y_continuous("Efficiency scores according to Jessica") +
scale_x_discrete("") +
theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# **I made a bar chart using ggplot. Geom_bar stands for bar chart. The x-axis became readable when I added theme in the sixth line. I ordered the graph from low to high by using reorder(Country, Score) in stead of Country for the x-axis. In the fourth and fifth lines I changed the names of the axes. Finally I made the bar of the netherlands red by adding fill=Country and scale_fill_manual. I removed the legend with Guides(fill=FALSE).**
